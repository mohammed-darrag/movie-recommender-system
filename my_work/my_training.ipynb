# %%
import platform
print(platform.python_version())
import sys
print(sys.executable)
# Out:
# 3.11.5
# g:\conda\envs\ml1\python.exe

# %%
# %pip install "numpy==2.2.3" "matplotlib==3.10.1" "pandas==2.2.3" "scikit-learn==1.6.1"
# Out:
# Requirement already satisfied: numpy==2.2.3 in g:\conda\envs\ml1\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib==3.10.1 in g:\conda\envs\ml1\lib\site-packages (3.10.1)
# Requirement already satisfied: pandas==2.2.3 in g:\conda\envs\ml1\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn==1.6.1 in g:\conda\envs\ml1\lib\site-packages (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.1) (25.0)
# Requirement already satisfied: pillow>=8 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in g:\conda\envs\ml1\lib\site-packages (from matplotlib==3.10.1) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in g:\conda\envs\ml1\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in g:\conda\envs\ml1\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in g:\conda\envs\ml1\lib\site-packages (from scikit-learn==1.6.1) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in g:\conda\envs\ml1\lib\site-packages (from scikit-learn==1.6.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in g:\conda\envs\ml1\lib\site-packages (from scikit-learn==1.6.1) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib==3.10.1) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# For Loop
for x in some_list:
    print(x)
# Out:
# 1
# 2.0
# three
# 4
# 5

# %%
some_string = 'Hello world'
some_int = 42
some_float = 42.0
some_bool = True
some_list = [1, 2.0, 'three', 4, 5]
some_tuple = (3, 4)
some_dictionary = {'one':1, 'two':2}

# %%
print(some_string)
print(some_dictionary)
print(some_list)
# Out:
# Hello world
# {'one': 1, 'two': 2}
# [1, 2.0, 'three', 4, 5]

# %%
print(some_tuple)
# Out:
# (3, 4)

# %%
# For Loop with index
for index, x in enumerate(some_list):
    print(f'{index}: {x}')
# Out:
# 0: 1
# 1: 2.0
# 2: three
# 3: 4
# 4: 5

# %%
for index, x in enumerate(some_list):
    print(f'{index}: {x}')
# Out:
# 0: 1
# 1: 2.0
# 2: three
# 3: 4
# 4: 5

# %%
# Looping over key-value pairs
for key, value in some_dictionary.items():
    print(f'Key {key} maps to {value}')
# Out:
# Key one maps to 1
# Key two maps to 2

# %%
for key, value in some_dictionary.items():
    print(f'key {key} maps to {value}')
# Out:
# key one maps to 1
# key two maps to 2

# %%
some_list[0]
# Out:
# 1

# %%
some_list[2: ]
# Out:
# ['three', 4, 5]

# %%
some_list.append(None)
some_list
# Out:
# [1, 2.0, 'three', 4, 5, None]

# %%
some_list.append("darrag")
some_list
# Out:
# [1, 2.0, 'three', 4, 5, None, 'darrag']

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if some_list[0] == 1:
    print('this should be printed')
else:
    print('this should be printed')
# Out:
# this should be printed

# %%
if some_list[-7] == 1:
    print('well done')
# Out:
# well done

# %%
import numpy as np

# %%
x = np.array([1, 3, 5])
x
# Out:
# array([1, 3, 5])

# %%
x.shape
# Out:
# (3,)

# %%
x = np.array([[1, 3, 5], [2,4,6]])
x
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
x.shape
# Out:
# (2, 3)

# %%
A = np.ones((2, 3))
A
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
x + A
# Out:
# array([[2., 4., 6.],
#        [3., 5., 7.]])

# %%
x * A
# Out:
# array([[1., 3., 5.],
#        [2., 4., 6.]])

# %%
2 * x
# Out:
# array([[ 2,  6, 10],
#        [ 4,  8, 12]])

# %%
x.transpose x.t
# Out:
#   Cell In[46], line 1
#     x.transpose x.t
#                 ^
# SyntaxError: invalid syntax

# %%
x_transpose = x.T
x_transpose
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
xmx = x_transpose @ x

# %%
xmx
# Out:
# array([[ 5, 11, 17],
#        [11, 25, 39],
#        [17, 39, 61]])

# %%
x
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
data = x.T
x
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
print(data.min())
print(data.max())
print(data.sum())
# Out:
# 1
# 6
# 21

# %%
data = np.array([[1, 2], [5, 3], [4, 6]])
data
# Out:
# array([[1, 2],
#        [5, 3],
#        [4, 6]])

# %%
data.max(axis=0)
# Out:
# array([5, 6])

# %%
data.max(axis=1)
# Out:
# array([2, 5, 6])

# %%
data = x.T
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
data[1:0,:]
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
data[1:3,:]
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
data[1:4,:]
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
data[1:6,:]
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
data[1:1,:]
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
data[1:2,:]
# Out:
# array([[3, 4]])

# %%
data[0:4:5]
# Out:
# array([[1, 2]])

# %%
data[1:2,:0]
# Out:
# array([], shape=(1, 0), dtype=int64)

# %%
data = np.arange(1, 7)
data
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
n = 10
y = np.random.rand(n)
y_hat = np.random.rand(n)

# %%
y
# Out:
# array([0.4185086 , 0.96757586, 0.17164356, 0.03624747, 0.60017043,
#        0.37054704, 0.91545469, 0.09420346, 0.82908766, 0.15762376])

# %%
n = 10
y = np.random.rand(n)
y_hat = np.random.rand(n)

# %%
y
# Out:
# array([0.10241833, 0.82520098, 0.42252706, 0.40626729, 0.19836481,
#        0.18558264, 0.90444457, 0.88132777, 0.26751455, 0.26065563])

# %%
y_hat
# Out:
# array([0.9172767 , 0.59914703, 0.65287292, 0.43600969, 0.59311045,
#        0.70715168, 0.73110282, 0.65561718, 0.51982743, 0.34059964])

# %%
y.shape
# Out:
# (10,)

# %%
(y - y_hat)**2
# Out:
# array([0.66399416, 0.05110039, 0.05305921, 0.00088461, 0.15582412,
#        0.27203427, 0.03004736, 0.05094527, 0.06366179, 0.00639105])

# %%
E = np.mean(y - y_hat)**2
E
# Out:
# np.float64(0.028846030480045953)

# %%
from matplotlib import pyplot as plt

# %%
from sklearn import datasets
digits = datasets.load_digits()
data = digits.data

# %%
data.shape
# Out:
# (1797, 64)

# %%
data[0].shape
# Out:
# (64,)

# %%
data[0].reshape(8,8)
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
data[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data[0].shape
#
# NameError: name 'data' is not defined

# %%
data[3].shape
# Out:
# (64,)

# %%
data[1700].shape
# Out:
# (64,)

# %%
data = data.reshape(1797,8,8)
data.shape
# Out:
# (1797, 8, 8)

# %%
plt.imshow(data[0])

# %%
data[3, :,1]
# Out:
# array([0., 8., 2., 0., 0., 0., 0., 0.])

# %%
fig, axs = plt.subplots(5, 5, figsize=(10, 10)) # create a plot with 5x5 subplots
axs = axs.flatten()
for i in range(25):
    ax = axs[i]
    ax.imshow(data[i])

# %%
from sklearn.datasets import fetch_california_housing 
california_housing = fetch_california_housing(as_frame=True)
df = california_housing.frame
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
    df['Population']
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: Population, Length: 20640, dtype: float64

# %%
sliced_df =df[['HouseAge', 'Population']]
sliced_df
# Out:
#        HouseAge  Population
# 0          41.0       322.0
# 1          21.0      2401.0
# 2          52.0       496.0
# 3          52.0       558.0
# 4          52.0       565.0
# ...         ...         ...
# 20635      25.0       845.0
# 20636      18.0       356.0
# 20637      17.0      1007.0
# 20638      18.0       741.0
# 20639      16.0      1387.0
#
# [20640 rows x 2 columns]

# %%
sliced_df.to_numpy()
# Out:
# array([[  41.,  322.],
#        [  21., 2401.],
#        [  52.,  496.],
#        ...,
#        [  17., 1007.],
#        [  18.,  741.],
#        [  16., 1387.]], shape=(20640, 2))

# %%
df.iloc[:10 , 2:5]
# Out:
#    AveRooms  AveBedrms  Population
# 0  6.984127   1.023810       322.0
# 1  6.238137   0.971880      2401.0
# 2  8.288136   1.073446       496.0
# 3  5.817352   1.073059       558.0
# 4  6.281853   1.081081       565.0
# 5  4.761658   1.103627       413.0
# 6  4.931907   0.951362      1094.0
# 7  4.797527   1.061824      1157.0
# 8  4.294118   1.117647      1206.0
# 9  4.970588   0.990196      1551.0

# %%
df.mean(axis=0)
# Out:
# MedInc            3.870671
# HouseAge         28.639486
# AveRooms          5.429000
# AveBedrms         1.096675
# Population     1425.476744
# AveOccup          3.070655
# Latitude         35.631861
# Longitude      -119.569704
# MedHouseVal       2.068558
# dtype: float64

# %%
df.max(axis=1)
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Length: 20640, dtype: float64
