# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 4.2 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.3 MB 4.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.3 MB 5.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.3 MB 5.3 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.3 MB 5.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.3 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.3 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 5.8 MB/s  0:00:02
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
# ...

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/72.0 MB 4.8 MB/s eta 0:00:15
#    - -------------------------------------- 2.1/72.0 MB 5.3 MB/s eta 0:00:14
#    - -------------------------------------- 3.4/72.0 MB 5.4 MB/s eta 0:00:13
#    -- ------------------------------------- 4.5/72.0 MB 5.4 MB/s eta 0:00:13
#    --- ------------------------------------ 5.5/72.0 MB 5.2 MB/s eta 0:00:13
#    --- ------------------------------------ 6.8/72.0 MB 5.4 MB/s eta 0:00:13
#    ---- ----------------------------------- 8.1/72.0 MB 5.5 MB/s eta 0:00:12
#    ----- ---------------------------------- 9.4/72.0 MB 5.7 MB/s eta 0:00:11
#    ----- ---------------------------------- 10.7/72.0 MB 5.7 MB/s eta 0:00:11
#    ------ --------------------------------- 12.1/72.0 MB 5.7 MB/s eta 0:00:11
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # used to learning simple tree rules 
from sklearn.ensemble import RandomForestClassifier # used in bagging ,features 
from sklearn.model_selection import train_test_split # train one part of the data
from sklearn.metrics import accuracy_score # evaluate classifier model 
from xgboost import XGBClassifier # xgboost algorithm 
import matplotlib.pyplot as plt # used for visualixation 
RANDOM_STATE = 55 ## We will pass it to every sklearn call so we ensure reproducibility

# %%
# Load the dataset using pandas
df = pd.read_csv("heart.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load the dataset using pandas
# ----> 2 df = pd.read_csv("heart.csv")
#
# NameError: name 'pd' is not defined
