# %% [markdown]
# # Introduction to Python and NumPy

# %%
import sys
print(sys.executable)
# Out:
# g:\conda\envs\ml1\python.exe

# %% [markdown]
# ## Installation

# %%
import platform
print(platform.python_version())
import sys
print(sys.executable)
# Out:
# 3.11.5
# g:\conda\envs\ml1\python.exe

# %% [markdown]
# Our recommendation is to use [Miniconda](https://docs.anaconda.com/miniconda/) to manage your `Python` environment.
# If you have not installed Miniconda or Anaconda yet, follow the installation instructions [here](https://docs.anaconda.com/miniconda/#quick-command-line-install).
#
# As soon as you have installed Miniconda, you can create a new environment with the name `ml1` by running
# ```bash
# conda create -n "ml1" python=3.11.5
# ```
#
# After creating the environment, use the following command to activate it:
# ```bash
# conda activate ml1
# ```
#
# If you open this Jupyter notebook in VSCode, select the Python interpreter in the `ml1` conda environment in the upper right corner.
# VSCode will then prompt you to install the `ipykernel` package, which you should install.

# %% [markdown]
# ## IDEs
#
# Recommended:
#
# + [Visual Studio Code](https://code.visualstudio.com/) (with the `Jupyter` and `Python` extensions)
# + [Jetbrains PyCharm](https://www.jetbrains.com/pycharm/) (The student version is totally sufficient for this course, but you can also get the professional edition for free with your university email (https://www.jetbrains.com/shop/eform/students).)

# %% [markdown]
# ## Additional Resource
#
# [learnpython.org](https://www.learnpython.org/)

# %% [markdown]
# # Setup

# %%
# %pip install "numpy==2.2.3" "matplotlib==3.10.1" "pandas==2.2.3" "scikit-learn==1.6.1"
# Out:
# Collecting numpy==2.2.3
#   Downloading numpy-2.2.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib==3.10.1
#   Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn==1.6.1
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.10.1)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib==3.10.1)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.10.1)
#   Downloading fonttools-4.60.1-cp311-cp311-win_amd64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.10.1)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.1) (25.0)
# Collecting pillow>=8 (from matplotlib==3.10.1)
#   Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.10.1)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from matplotlib==3.10.1) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.3)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn==1.6.1)
#   Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.6.1)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\darrag\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib==3.10.1) (1.17.0)
# Downloading numpy-2.2.3-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 2.4 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/12.9 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.9 MB 2.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.9 MB 2.1 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.9 MB 2.1 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.9 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 3.1/12.9 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.9 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.9 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 4.7/12.9 MB 2.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.9 MB 2.3 MB/s eta 0:00:04
#    ------------------ --------------------- 6.0/12.9 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.9 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.3/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------ --------------- 7.9/12.9 MB 2.5 MB/s eta 0:00:03
#    -------------------------- ------------- 8.7/12.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.2/12.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 10.0/12.9 MB 2.6 MB/s eta 0:00:02
#    --------------------------------- ------ 10.7/12.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/12.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 2.6 MB/s  0:00:04
# Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.1 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 3.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 3.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 2.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 2.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.4 MB/s  0:00:03
# Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 4.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.6 MB 3.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.6 MB 2.8 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.6 MB 3.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.6 MB 3.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.6 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.6 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.5/11.6 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.6 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 5.5/11.6 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 6.0/11.6 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.3/11.6 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.8/11.6 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.6 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.6 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.4/11.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 9.2/11.6 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.6 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 2.3 MB/s  0:00:04
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.1 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.1 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.1 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.1 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.1 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/11.1 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.1 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.1 MB 2.3 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.1 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.1 MB 2.5 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.1 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.1 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 2.2 MB/s  0:00:05
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.9 MB/s  0:00:01
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.0 MB 2.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.0 MB 1.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.8/7.0 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.0 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/7.0 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/7.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/7.0 MB 2.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.0 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.0 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 2.0 MB/s  0:00:03
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.2-cp311-cp311-win_amd64.whl (38.7 MB)
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.7 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.7 MB 1.7 MB/s eta 0:00:23
#    - -------------------------------------- 1.0/38.7 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.3/38.7 MB 1.7 MB/s eta 0:00:22
#    - -------------------------------------- 1.8/38.7 MB 1.8 MB/s eta 0:00:21
#    -- ------------------------------------- 2.4/38.7 MB 1.9 MB/s eta 0:00:20
#    -- ------------------------------------- 2.9/38.7 MB 2.0 MB/s eta 0:00:18
#    --- ------------------------------------ 3.1/38.7 MB 2.1 MB/s eta 0:00:17
#    --- ------------------------------------ 3.7/38.7 MB 2.0 MB/s eta 0:00:18
#    ---- ----------------------------------- 4.5/38.7 MB 2.1 MB/s eta 0:00:16
#    ----- ---------------------------------- 5.0/38.7 MB 2.2 MB/s eta 0:00:16
#    ----- ---------------------------------- 5.5/38.7 MB 2.2 MB/s eta 0:00:15
#    ------ --------------------------------- 6.0/38.7 MB 2.2 MB/s eta 0:00:15
#    ------ --------------------------------- 6.3/38.7 MB 2.2 MB/s eta 0:00:15
#    ------ --------------------------------- 6.6/38.7 MB 2.2 MB/s eta 0:00:15
#    ------- -------------------------------- 6.8/38.7 MB 2.1 MB/s eta 0:00:16
#    ------- -------------------------------- 7.3/38.7 MB 2.1 MB/s eta 0:00:16
#    ------- -------------------------------- 7.6/38.7 MB 2.1 MB/s eta 0:00:16
#    -------- ------------------------------- 8.1/38.7 MB 2.0 MB/s eta 0:00:16
#    -------- ------------------------------- 8.7/38.7 MB 2.0 MB/s eta 0:00:15
#    --------- ------------------------------ 9.2/38.7 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 9.4/38.7 MB 2.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 10.0/38.7 MB 2.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 10.5/38.7 MB 2.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.0/38.7 MB 2.1 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.3/38.7 MB 2.0 MB/s eta 0:00:14
#    ------------ --------------------------- 11.8/38.7 MB 2.1 MB/s eta 0:00:14
#    ------------ --------------------------- 12.3/38.7 MB 2.1 MB/s eta 0:00:13
#    ------------- -------------------------- 12.6/38.7 MB 2.1 MB/s eta 0:00:13
#    ------------- -------------------------- 13.1/38.7 MB 2.1 MB/s eta 0:00:13
#    -------------- ------------------------- 13.6/38.7 MB 2.1 MB/s eta 0:00:13
#    -------------- ------------------------- 13.9/38.7 MB 2.0 MB/s eta 0:00:13
#    -------------- ------------------------- 14.2/38.7 MB 2.0 MB/s eta 0:00:13
#    -------------- ------------------------- 14.4/38.7 MB 2.0 MB/s eta 0:00:13
#    -------------- ------------------------- 14.4/38.7 MB 2.0 MB/s eta 0:00:13
#    --------------- ------------------------ 14.9/38.7 MB 1.9 MB/s eta 0:00:13
#    --------------- ------------------------ 15.5/38.7 MB 1.9 MB/s eta 0:00:12
#    ---------------- ----------------------- 16.0/38.7 MB 2.0 MB/s eta 0:00:12
#    ---------------- ----------------------- 16.3/38.7 MB 2.0 MB/s eta 0:00:12
#    ----------------- ---------------------- 16.5/38.7 MB 1.9 MB/s eta 0:00:12
#    ----------------- ---------------------- 17.0/38.7 MB 1.9 MB/s eta 0:00:12
#    ------------------ --------------------- 17.8/38.7 MB 2.0 MB/s eta 0:00:11
#    ------------------ --------------------- 18.4/38.7 MB 2.0 MB/s eta 0:00:11
#    ------------------- -------------------- 19.1/38.7 MB 2.0 MB/s eta 0:00:10
#    -------------------- ------------------- 19.7/38.7 MB 2.0 MB/s eta 0:00:10
#    -------------------- ------------------- 19.9/38.7 MB 2.0 MB/s eta 0:00:10
#    --------------------- ------------------ 20.4/38.7 MB 2.0 MB/s eta 0:00:10
#    --------------------- ------------------ 21.0/38.7 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 21.5/38.7 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 22.0/38.7 MB 2.0 MB/s eta 0:00:09
#    ----------------------- ---------------- 22.5/38.7 MB 2.1 MB/s eta 0:00:08
#    ----------------------- ---------------- 23.1/38.7 MB 2.1 MB/s eta 0:00:08
#    ------------------------ --------------- 23.9/38.7 MB 2.1 MB/s eta 0:00:08
#    ------------------------- -------------- 24.4/38.7 MB 2.1 MB/s eta 0:00:07
#    ------------------------- -------------- 24.9/38.7 MB 2.1 MB/s eta 0:00:07
#    -------------------------- ------------- 25.2/38.7 MB 2.1 MB/s eta 0:00:07
#    -------------------------- ------------- 25.4/38.7 MB 2.1 MB/s eta 0:00:07
#    -------------------------- ------------- 25.7/38.7 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 26.0/38.7 MB 2.0 MB/s eta 0:00:07
#    --------------------------- ------------ 26.2/38.7 MB 2.0 MB/s eta 0:00:07
#    --------------------------- ------------ 26.5/38.7 MB 2.0 MB/s eta 0:00:07
#    --------------------------- ------------ 26.7/38.7 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 26.7/38.7 MB 2.0 MB/s eta 0:00:06
#    --------------------------- ------------ 27.0/38.7 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.3/38.7 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.3/38.7 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.5/38.7 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.8/38.7 MB 1.9 MB/s eta 0:00:06
#    ----------------------------- ---------- 28.0/38.7 MB 1.9 MB/s eta 0:00:06
#    ----------------------------- ---------- 28.8/38.7 MB 1.9 MB/s eta 0:00:06
#    ------------------------------ --------- 29.1/38.7 MB 1.9 MB/s eta 0:00:06
#    ------------------------------ --------- 29.4/38.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 29.6/38.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 29.9/38.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 29.9/38.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------- -------- 30.4/38.7 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 30.7/38.7 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 30.9/38.7 MB 1.8 MB/s eta 0:00:05
#    -------------------------------- ------- 31.2/38.7 MB 1.8 MB/s eta 0:00:05
#    -------------------------------- ------- 31.5/38.7 MB 1.8 MB/s eta 0:00:04
#    -------------------------------- ------- 31.7/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.0/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.0/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.2/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.5/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.8/38.7 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 32.8/38.7 MB 1.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.0/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.3/38.7 MB 1.7 MB/s eta 0:00:04
#    ---------------------------------- ----- 33.6/38.7 MB 1.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.8/38.7 MB 1.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.3/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 34.9/38.7 MB 1.7 MB/s eta 0:00:03
#    ------------------------------------ --- 35.4/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 35.9/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.7 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/38.7 MB 1.7 MB/s eta 0:00:02
#    -------------------------------------- - 37.0/38.7 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 1.7 MB/s  0:00:22
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, contourpy, scikit-learn, matplotlib
#
#    ----------------------------------------  0/15 [pytz]
#    ----------------------------------------  0/15 [pytz]
#    ----------------------------------------  0/15 [pytz]
#    -- -------------------------------------  1/15 [tzdata]
#    -- -------------------------------------  1/15 [tzdata]
#    -- -------------------------------------  1/15 [tzdata]
#    -------- -------------------------------  3/15 [pyparsing]
#    -------- -------------------------------  3/15 [pyparsing]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ---------- -----------------------------  4/15 [pillow]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ------------- --------------------------  5/15 [numpy]
#    ---------------- -----------------------  6/15 [kiwisolver]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    ------------------ ---------------------  7/15 [joblib]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    --------------------- ------------------  8/15 [fonttools]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    -------------------------- ------------- 10/15 [scipy]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    ----------------------------- ---------- 11/15 [pandas]
#    -------------------------------- ------- 12/15 [contourpy]
#    -------------------------------- ------- 12/15 [contourpy]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ---------------------------------- ----- 13/15 [scikit-learn]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ------------------------------------- -- 14/15 [matplotlib]
#    ---------------------------------------- 15/15 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.1 numpy-2.2.3 pandas-2.2.3 pillow-12.0.0 pyparsing-3.2.5 pytz-2025.2 scikit-learn-1.6.1 scipy-1.16.2 threadpoolctl-3.6.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Basics and Syntax

# %%
some_string = 'Hello World'
some_int = 42
some_float = 42.0
some_bool = True
some_list = [1, 2.0, 'three', 4, 5]
some_tuple = (3, 4)
some_dictionary = {'one': 1, 'two': 2} # key-value pairs of arbitrary type

# %%
# For Loop
for x in some_list:
    print(x)
# Out:
# 1
# 2.0
# three
# 4
# 5

# %%
# For Loop with index
for index, x in enumerate(some_list):
    print(f'{index}: {x}')
# Out:
# 0: 1
# 1: 2.0
# 2: three
# 3: 4
# 4: 5

# %%
# Looping over key-value pairs
for key, value in some_dictionary.items():
    print(f'Key {key} maps to {value}')
# Out:
# Key one maps to 1
# Key two maps to 2

# %%
some_list[0] # first element (0-indexing)
# Out:
# 1

# %%
# some_list[:2] # slicing from index 0 (inclusive) to index 2 (exclusive)
some_list[2:]
# this is the same as some_list[:2]
# Out:
# ['three', 4, 5]

# %%
some_list.append(None) # special keyword None, similar to null or nullptr in other languages
some_list
# Out:
# [1, 2.0, 'three', 4, 5, None]

# %%
if some_list[0] == 1:
    print('this should be printed')
else:
    print('this should not be printed')
# Out:
# this should be printed

# %%
if some_list[-1] is None:
    print('this should be printed')
# Out:
# this should be printed

# %% [markdown]
# # NumPy
#
# https://numpy.org
#
# + "The fundamental package for scientific computing with Python"
# + Builds around N-dimensional arrays (i.e., tensors) of numbers (floats, ints, bools)
# + "Array computing", "Linear Algebra Programs"
# + **Extremely important in all of scientific computing**
# + Especially so in **Machine Learning**, **Deep Learning**, **Data Science**

# %%
import numpy as np

# %%
x = np.array([1, 3, 5]) # 1D numpy array
x
# Out:
# array([1, 3, 5])

# %%
x.shape
# Out:
# (3,)

# %%
X = np.array([[1, 3, 5], [2, 4, 6]]) # 2D numpy array
X
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
X.shape
# Out:
# (2, 3)

# %%
A = np.ones((2, 3)) # There's also np.zeros
A
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
X + A # element-wise operation (+, -, *, /)
# Out:
# array([[2., 4., 6.],
#        [3., 5., 7.]])

# %%
2 * X # multiplies *every element* in X by 2
# Out:
# array([[ 2,  6, 10],
#        [ 4,  8, 12]])

# %%
# Let's transpose X
X_transposed = X.T
X_transposed
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
XtX = X_transposed @ X # matrix multiply
XtX
# Out:
# array([[ 5, 11, 17],
#        [11, 25, 39],
#        [17, 39, 61]])

# %% [markdown]
# ## Matrix Aggregation

# %%
data = X.T
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# ![title](https://jalammar.github.io/images/numpy/numpy-matrix-aggregation-1.png)
#
# Source: https://jalammar.github.io/visual-numpy/

# %%
print(data.max()) 
print(data.min()) 
print(data.sum())
# Out:
# 6
# 1
# 21

# %%
data = np.array([[1, 2], [5, 3], [4, 6]])
data
# Out:
# array([[1, 2],
#        [5, 3],
#        [4, 6]])

# %% [markdown]
# ![title](https://jalammar.github.io/images/numpy/numpy-matrix-aggregation-4.png)
#
# Source: https://jalammar.github.io/visual-numpy/

# %%
data.max(axis=0)
# Out:
# array([5, 6])

# %%
data.max(axis=1)
# Out:
# array([2, 5, 6])

# %% [markdown]
# ## Matrix Indexing

# %%
data = X.T
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# ![title](https://jalammar.github.io/images/numpy/numpy-matrix-indexing.png)
#
# Source: https://jalammar.github.io/visual-numpy/

# %%
data[1:3,:]
# Out:
# array([[3, 4],
#        [5, 6]])

# %% [markdown]
# ## Reshaping

# %%
data = np.arange(1, 7)
data
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# ![title](https://jalammar.github.io/images/numpy/numpy-reshape.png)
#
# Source: https://jalammar.github.io/visual-numpy/

# %%
data.reshape(2, 3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ## Implementing the Mean Squared Error function

# %% [markdown]
# Let $\mathbf{y} = (y_1, \dots, y_n)^T$ and $\hat{\mathbf{y}} = (\hat{y}_1, \dots, \hat{y}_n)^T$.
# The *mean squared error function* is given by
# $$E(\mathbf{y}, \hat{\mathbf{y}}) = \frac{1}{n} \sum_{i=1}^n (y_i - \hat{y}_i)^2 $$

# %%
n = 10
y = np.random.rand(n)
y_hat = np.random.rand(n)

# %%
y
# Out:
# array([0.76926589, 0.61652704, 0.01081519, 0.37789147, 0.97328932,
#        0.54678725, 0.71776601, 0.75772501, 0.24387433, 0.04828295])

# %%
y_hat
# Out:
# array([0.3461036 , 0.61616222, 0.60829832, 0.18449325, 0.03871229,
#        0.29708763, 0.84769146, 0.45075516, 0.37984954, 0.47501224])

# %%
(y - y_hat)**2
# Out:
# array([1.79066325e-01, 1.33096185e-07, 3.56986089e-01, 3.74028699e-02,
#        8.73434216e-01, 6.23499017e-02, 1.68806241e-02, 9.42304929e-02,
#        1.84892569e-02, 1.82097888e-01])

# %%
E = np.mean((y - y_hat)**2)
E
# Out:
# np.float64(0.18209377961696332)

# %% [markdown]
# ## Example: Image Dataset

# %% [markdown]
# We will use `matplotlib` for plotting and `sklearn` to import the image dataset.

# %%
from matplotlib import pyplot as plt

# %%
from sklearn import datasets
digits = datasets.load_digits()
data = digits.data

# %%
data.shape
# Out:
# (1797, 64)

# %%
data[0].shape
# Out:
# (64,)

# %%
data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
data[0].reshape(8, 8)
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
data = data.reshape(1797, 8, 8) # we can also do data.reshape(-1, 8, 8)
data.shape # We can think of this as a collection of 1797 (8,8) matrices
# Out:
# (1797, 8, 8)

# %%
plt.imshow(data[0])

# %%
data[3, :, 1] # this would slice out the second column in image with index 3
# Out:
# array([0., 8., 2., 0., 0., 0., 0., 0.])

# %% [markdown]
# ## Plotting with matplotlib

# %%
fig, axs = plt.subplots(5, 5, figsize=(10, 10)) # create a plot with 5x5 subplots
axs = axs.flatten()
for i in range(25):
    ax = axs[i]
    ax.imshow(data[i])

# %% [markdown]
# # Pandas

# %% [markdown]
# **pandas** is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool [[1]](https://pandas.pydata.org/).

# %%
from sklearn.datasets import fetch_california_housing
california_housing = fetch_california_housing(as_frame=True)
df = california_housing.frame

df # this is a pandas DataFrame
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %% [markdown]
# Often, we can think of the `DataFrame` as a dictionary of column names and the corresponding column values:

# %%
df['HouseAge'] # get the 'HouseAge' column
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64

# %%
sliced_df = df[['HouseAge', 'Population']] # pass a *list* of strings to slice out multiple columns
sliced_df
# Out:
#        HouseAge  Population
# 0          41.0       322.0
# 1          21.0      2401.0
# 2          52.0       496.0
# 3          52.0       558.0
# 4          52.0       565.0
# ...         ...         ...
# 20635      25.0       845.0
# 20636      18.0       356.0
# 20637      17.0      1007.0
# 20638      18.0       741.0
# 20639      16.0      1387.0
#
# [20640 rows x 2 columns]

# %%
sliced_df.to_numpy() # we can easily convert DataFrames to numpy arrays
# Out:
# array([[  41.,  322.],
#        [  21., 2401.],
#        [  52.,  496.],
#        ...,
#        [  17., 1007.],
#        [  18.,  741.],
#        [  16., 1387.]], shape=(20640, 2))

# %% [markdown]
# With `df.iloc`, you can slice a DataFrame like a numpy array

# %%
df.iloc[:10, 2:5] # gets the first 10 rows and columns with index 2, 3, 4
# Out:
#    AveRooms  AveBedrms  Population
# 0  6.984127   1.023810       322.0
# 1  6.238137   0.971880      2401.0
# 2  8.288136   1.073446       496.0
# 3  5.817352   1.073059       558.0
# 4  6.281853   1.081081       565.0
# 5  4.761658   1.103627       413.0
# 6  4.931907   0.951362      1094.0
# 7  4.797527   1.061824      1157.0
# 8  4.294118   1.117647      1206.0
# 9  4.970588   0.990196      1551.0

# %% [markdown]
# `DataFrames` support a `numpy`-like API:

# %%
df.mean(axis=0) # mean per column (default)
# Out:
# MedInc            3.870671
# HouseAge         28.639486
# AveRooms          5.429000
# AveBedrms         1.096675
# Population     1425.476744
# AveOccup          3.070655
# Latitude         35.631861
# Longitude      -119.569704
# MedHouseVal       2.068558
# dtype: float64

# %%
df.max(axis=1) # max value per row
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Length: 20640, dtype: float64
